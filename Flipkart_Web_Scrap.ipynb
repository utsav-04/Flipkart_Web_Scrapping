# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup

# %%
httpObject=urlopen("https://www.flipkart.com/q/best-laptops-under-rs-50000")
webdata=httpObject.read()
print(webdata)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.5ffd15.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/><link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/><meta name="twitter:card" content="app"><meta name="twitter:site" content="@flipkart"><meta name="twitter:creator" content="@flipkart"><meta name="twitter:title" content="Best Laptops Under Rs 50000 Online at India&#x27;s Best Online Shopping Store  | Flipkart.com"><meta name="twitter:description" content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD."><meta name="twitter:app:country" content="in"><meta name="al:ios:app_name" content="Flipkart"><meta name="al:ios:app_store_id" content="742044692"><meta name="twitter:app:name:iphone" content="Flipkart"><meta name="twitter:app:id:iphone" content="742044692"><meta name="twitter:app:url:iphone" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:ipad" content="Flipkart"><meta name="twitter:app:id:ipad" content="742044692"><meta name="twitter:app:url:ipad" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:googleplay" content="Flipkart"><meta name="twitter:app:id:googleplay" content="com.flipkart.android"><meta name="twitter:app:url:googleplay" content="http://dl.flipkart.com/dl/home?"><style>#container {\n\t\t\theight: 100%;\n\t\t}</style>  <link rel="stylesheet" href="///fk-cp-zion/css/Browse.chunk.55ae09.css"/><title>Best Laptops Under Rs 50000 Online at India&#x27;s Best Online Shopping Store  | Flipkart.com</title><meta name="og_title" property="og:title" content="Best Laptops Under Rs 50000 Online at India&#x27;s Best Online Shopping Store  | Flipkart.com"/><meta name="Keywords" content="Best Laptops Under Rs 50000, Best Laptops Under Rs 50000 Store, Buy Best Laptops Under Rs 50000 Online"/> <meta name="Description" content="Buy Best/Top Branded Laptops Under Rs 50000 -  Check Price in India and Buy Online. Also Read Latest Product Reviews &amp; More  - Flipkart.com"/><meta property="og:description" content="Buy Best/Top Branded Laptops Under Rs 50000 -  Check Price in India and Buy Online. Also Read Latest Product Reviews &amp; More  - Flipkart.com"/>  <link rel="canonical" href="https://www.flipkart.com/q/best-laptops-under-rs-50000"/> <link rel="alternate" href="android-app://com.flipkart.android/flipkart/de_sq_seg_--_search.flipkart.com_--_best+laptops+under+rs+50000"/>    <meta name="og_url" property="og:url" content="https://www.flipkart.com/q/best-laptops-under-rs-50000"/><meta name="msvalidate.01" content="F4EEB3A0AFFDD385992A06E6920C0AC3"/> <!--[if IE 9 ]>\n\t<script nonce="7033652590776420741">\n\t\twindow.browserVersion = \'IE9\';\n\t\tdocument.documentElement.className += \' ie9\';\n\t</script>\n\t<![endif]--><!--[if !IE]><!--><script nonce="7033652590776420741">if (/*@cc_on!@*/false) {\n\t\t\twindow ...

# %%
soupdata=soup(webdata)

# %%
containers=soupdata.findAll('div',{'class':'_2kHMtA'})
print(len(containers))
# Out:
# 24

# %%
for container in containers:
  product=container.findAll('div',{'class':'_4rR01T'})
  print(product[0].text)
# Out:
# Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 15ITL6 Thin and Ligh...
# Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA...
# HP Intel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s- fr4000TU Thin and Light Laptop
# HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2223AU Thin and Light Laptop
# HP 14s Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop
# HP (2023) Intel 12th Gen N305 Core i3 - (8 GB/512 GB SSD/Windows 11 Home) 14-Ep0068TU Thin and Light L...
# HP 15s Intel Core i3 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq5007TU Thin and Light Laptop
# Lenovo Ideapad Gaming 3 AMD Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/N...
# MSI Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/Arc A370M Intel ARC) Thin GF63 ...
# HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 14s-fq1092au Thin and Light Laptop
# MSI Ryzen 5 Hexa Core 7530U - (8 GB/512 GB SSD/Windows 11 Home) Modern 14 C7M-063IN Thin and Light Lap...
# MSI Ryzen 5 Hexa Core 7530U - (16 GB/512 GB SSD/Windows 11 Home) Modern 14 C7M-062IN Thin and Light La...
# HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 11 Home) 15s- eq2182AU Thin and Light Laptop
# HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 11 Home) 15s-eq2143au Thin and Light Laptop
# MSI Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX 1650) GF63 Th...
# MSI Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX 1650) GF63 Th...
# Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15IAU7 Thin and Light...
# HP Victus Gaming Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeFor...
# HP 15s (2023) Intel Core i3 13th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-fd0019TU Thin and Light La...
# HP 15s (2023) Intel Core i3 13th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-fd0006TU Thin and Light La...
# HP Victus Ryzen 7 Octa Core 5800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX...
# HP Victus Ryzen 5 Hexa Core 5600H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX...
# MSI Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) Modern 14 C12M-439IN Thin and Light Laptop
# HP 15s (2023) Intel Core i3 13th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-fd0018TU Thin and Light La...

# %%
import re
for container in containers:
  info=container.findAll('li',{'class':'rgWa7D'})
  Processor=info[0].text
  Ram=info[1].text
  Storage=info[3].text
  print(Processor,Ram,Storage)
# Out:
# Intel Core i5 Processor (11th Gen) 16 GB DDR4 RAM 512 GB SSD
# Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD
# Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD
# Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 256 GB SSD
# Intel Core i3 Processor 8 GB DDR4 RAM 512 GB SSD
# Intel Core i3 Processor (12th Gen) 8 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD
# Intel Core i5 Processor (12th Gen) 16 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 16 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 16 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 3 Quad Core Processor 8 GB DDR4 RAM 512 GB SSD
# Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD
# Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD
# Intel Core i5 Processor (12th Gen) 8 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD
# Intel Core i3 Processor (13th Gen) 8 GB DDR4 RAM 512 GB SSD
# Intel Core i3 Processor (13th Gen) 8 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 7 Octa Core Processor 16 GB DDR4 RAM 512 GB SSD
# AMD Ryzen 5 Hexa Core Processor 16 GB DDR4 RAM 512 GB SSD
# Intel Core i5 Processor (12th Gen) 16 GB DDR4 RAM 512 GB SSD
# Intel Core i3 Processor (13th Gen) 8 GB DDR4 RAM 512 GB SSD

# %%
import re
for container in containers:

  Rating=container.find('span',{'class':'_2_R_DZ'})
  try:
    ratRev=re.findall('\d+,?\d*',Rating.text)
    Ratings=ratRev[0]
    Reviews=ratRev[1]
  except:
    Ratings=0
    Reviews=0
  print(Ratings, Reviews)
# Out:
# 922 65
# 3,664 320
# 1,286 87
# 103 10
# 3,554 294
# 15 1
# 1,008 116
# 310 27
# 0 0
# 2,723 255
# 200 27
# 200 27
# 901 95
# 2,630 286
# 1,234 132
# 0 0
# 694 57
# 184 18
# 74 8
# 74 8
# 98 9
# 302 33
# 105 15
# 74 8

# %%
import re
for container in containers:
  CurrentPrice=container.find('div',{'class':'_30jeq3 _1_WHN1'}).text
  print(CurrentPrice)
# Out:
# ₹48,990
# ₹48,990
# ₹49,990
# ₹40,999
# ₹35,990
# ₹40,990
# ₹41,390
# ₹48,990
# ₹49,990
# ₹43,990
# ₹39,990
# ₹44,990
# ₹51,890
# ₹35,990
# ₹49,990
# ₹47,990
# ₹49,990
# ₹53,990
# ₹46,990
# ₹46,990
# ₹76,990
# ₹65,990
# ₹45,990
# ₹46,990

# %%
import re
for container in containers:
  mrp = container.find('div',{'class':'_3I9_wc _27UcVY'})
  try:
    MRP=mrp.text
  except:
    MRP=0
  print(MRP)
# Out:
# ₹68,190
# ₹70,790
# ₹56,903
# ₹49,631
# ₹47,279
# ₹51,134
# ₹56,261
# ₹72,990
# ₹64,990
# ₹55,691
# ₹61,990
# ₹64,990
# ₹62,754
# ₹47,147
# ₹67,990
# ₹67,990
# ₹76,890
# ₹66,769
# ₹69,083
# ₹54,552
# ₹95,554
# ₹80,587
# ₹67,990
# ₹54,522

# %%
import re
for container in containers:

  product=container.find('div',{'class':'_4rR01T'})
  ProductName=product.text.split('-')[0].strip()
  print(ProductName)
# Out:
# Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen
# Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen
# HP Intel Core i5 11th Gen
# HP Ryzen 5 Hexa Core 5500U
# HP 14s Intel Core i3 11th Gen
# HP (2023) Intel 12th Gen N305 Core i3
# HP 15s Intel Core i3 12th Gen
# Lenovo Ideapad Gaming 3 AMD Ryzen 5 Hexa Core 5600H
# MSI Core i5 12th Gen
# HP Ryzen 5 Hexa Core 5500U
# MSI Ryzen 5 Hexa Core 7530U
# MSI Ryzen 5 Hexa Core 7530U
# HP Ryzen 5 Hexa Core 5500U
# HP Ryzen 3 Quad Core 5300U
# MSI Core i5 11th Gen
# MSI Core i5 11th Gen
# Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen
# HP Victus Gaming Ryzen 5 Hexa Core 5600H
# HP 15s (2023) Intel Core i3 13th Gen
# HP 15s (2023) Intel Core i3 13th Gen
# HP Victus Ryzen 7 Octa Core 5800H
# HP Victus Ryzen 5 Hexa Core 5600H
# MSI Core i5 12th Gen
# HP 15s (2023) Intel Core i3 13th Gen

# %%
import re
for container in containers:
  star=container.find('div',{'class':'_3LWZlK'})
  try:
    Stars=star.text
  except:
    Stars=0
  print(Stars)
# Out:
# 4.2
# 4.3
# 4.3
# 4.3
# 4.3
# 4.5
# 4.3
# 4.3
# 0
# 4.3
# 4.4
# 4.4
# 4.3
# 4.2
# 4.3
# 0
# 4.2
# 4.3
# 4.1
# 4.1
# 4.3
# 4.3
# 4.2
# 4.1

# %%
f=open('Flipkart_scrap.csv','wb')
f.write('ProductName,Stars,Ratings,Reviews,MRP,CurrentPrice,Processor,Ram,Storage,ImageUrl\n'.encode())
import re
for container in containers:
  product=container.find('div',{'class':'_4rR01T'})
  ProductName=product.text.split('-')[0].strip()

  star=container.find('div',{'class':'_3LWZlK'})
  try:
    Stars=star.text
  except:
    Stars=0

  Rating=container.find('span',{'class':'_2_R_DZ'})
  try:
    ratRev=re.findall('\d+,?\d*',Rating.text)
    Ratings=ratRev[0].replace(',','')
    Reviews=ratRev[1].replace(',','')
  except:
    Ratings=0
    Reviews=0

  CurrentPrice=container.find('div',{'class':'_30jeq3 _1_WHN1'}).text.replace(',','')

  mrp = container.find('div',{'class':'_3I9_wc _27UcVY'})
  try:
    MRP=mrp.text.replace(',','')
  except:
    MRP=0

  info=container.findAll('li',{'class':'rgWa7D'})
  Processor=info[0].text
  Ram=info[1].text
  Storage=info[3].text

  Image=container.img
  ImageUrl=Image.get('src')
  print(ProductName,Stars,Ratings,Reviews,MRP,CurrentPrice,Processor,Ram,Storage,ImageUrl)
  f.write(f"{ProductName},{Stars},{Ratings},{Reviews},{MRP},{CurrentPrice},{Processor},{Ram},{Storage},{ImageUrl}\n".encode())
  print('\n')
f.close()
# Out:
# Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen 4.2 922 65 ₹68190 ₹48990 Intel Core i5 Processor (11th Gen) 16 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/7/p/i/-original-imagrh4denyatghe.jpeg?q=70
#
#
# Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen 4.3 3664 320 ₹70790 ₹48990 Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/ks99aq80/computer/y/z/7/na-gaming-laptop-lenovo-original-imag5ve3jvhgvsnx.jpeg?q=70
#
#
# HP Intel Core i5 11th Gen 4.3 1286 87 ₹56903 ₹49990 Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/f/a/8/-original-imagp7pf86vm9mmj.jpeg?q=70
#
#
# HP Ryzen 5 Hexa Core 5500U 4.3 103 10 ₹49631 ₹40999 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/s/7/4/-original-imagp8xzmyz8jyua.jpeg?q=70
#
#
# HP 14s Intel Core i3 11th Gen 4.3 3554 294 ₹47279 ₹35990 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 256 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/4/v/9/-original-imagp7pfeutcgxrn.jpeg?q=70
#
#
# HP (2023) Intel 12th Gen N305 Core i3 4.5 15 1 ₹51134 ₹40990 Intel Core i3 Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/r/r/2/-original-imagregrn6h96s9a.jpeg?q=70
#
#
# HP 15s Intel Core i3 12th Gen 4.3 1008 116 ₹56261 ₹41390 Intel Core i3 Processor (12th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/o/l/e/-original-imagphhhan259czj.jpeg?q=70
#
#
# Lenovo Ideapad Gaming 3 AMD Ryzen 5 Hexa Core 5600H 4.3 310 27 ₹72990 ₹48990 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/kynb6vk0/computer/k/j/a/-original-imagaufne7h4hgbz.jpeg?q=70
#
#
# MSI Core i5 12th Gen 0 0 0 ₹64990 ₹49990 Intel Core i5 Processor (12th Gen) 16 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/l2qhjm80/computer/l/t/g/gf63-thin-11uc-867in-gaming-laptop-msi-original-imageyk5hzuthuyf.jpeg?q=70
#
#
# HP Ryzen 5 Hexa Core 5500U 4.3 2723 255 ₹55691 ₹43990 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/f/p/9/-original-imagp7pfnchrzxhr.jpeg?q=70
#
#
# MSI Ryzen 5 Hexa Core 7530U 4.4 200 27 ₹61990 ₹39990 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/f/p/e/-original-imagnqmwkz8nfwth.jpeg?q=70
#
#
# MSI Ryzen 5 Hexa Core 7530U 4.4 200 27 ₹64990 ₹44990 AMD Ryzen 5 Hexa Core Processor 16 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/f/p/e/-original-imagnqmwkz8nfwth.jpeg?q=70
#
#
# HP Ryzen 5 Hexa Core 5500U 4.3 901 95 ₹62754 ₹51890 AMD Ryzen 5 Hexa Core Processor 16 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/l/l/u/-original-imagp7pf4hphhyhu.jpeg?q=70
#
#
# HP Ryzen 3 Quad Core 5300U 4.2 2630 286 ₹47147 ₹35990 AMD Ryzen 3 Quad Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/x/u/6/-original-imagp7pfd65hfses.jpeg?q=70
#
#
# MSI Core i5 11th Gen 4.3 1234 132 ₹67990 ₹49990 Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/a/-original-imags9wb37rftsfy.jpeg?q=70
#
#
# MSI Core i5 11th Gen 0 0 0 ₹67990 ₹47990 Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/a/v/q/-original-imagrwq63pz43vze.jpeg?q=70
#
#
# Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 4.2 694 57 ₹76890 ₹49990 Intel Core i5 Processor (12th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/j/m/2/-original-imagpa5gadtkbm6y.jpeg?q=70
#
#
# HP Victus Gaming Ryzen 5 Hexa Core 5600H 4.3 184 18 ₹66769 ₹53990 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/k/i/r/-original-imagrmczdhd4zf8d.jpeg?q=70
#
#
# HP 15s (2023) Intel Core i3 13th Gen 4.1 74 8 ₹69083 ₹46990 Intel Core i3 Processor (13th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/q/b/g/-original-imagregrjumdnhrb.jpeg?q=70
#
#
# HP 15s (2023) Intel Core i3 13th Gen 4.1 74 8 ₹54552 ₹46990 Intel Core i3 Processor (13th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/b/k/p/-original-imagreh4byfrunc7.jpeg?q=70
#
#
# HP Victus Ryzen 7 Octa Core 5800H 4.3 98 9 ₹95554 ₹76990 AMD Ryzen 7 Octa Core Processor 16 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/g/x/f/-original-imagrmczkxwg5uvs.jpeg?q=70
#
#
# HP Victus Ryzen 5 Hexa Core 5600H 4.3 302 33 ₹80587 ₹65990 AMD Ryzen 5 Hexa Core Processor 16 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/t/4/-original-imagz9f6yd4es4s3.jpeg?q=70
#
#
# MSI Core i5 12th Gen 4.2 105 15 ₹67990 ₹45990 Intel Core i5 Processor (12th Gen) 16 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/f/p/e/-original-imagnqmwkz8nfwth.jpeg?q=70
#
#
# HP 15s (2023) Intel Core i3 13th Gen 4.1 74 8 ₹54522 ₹46990 Intel Core i3 Processor (13th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim2.flixcart.com/image/312/312/xif0q/computer/r/a/c/-original-imagreh9cuzdgut9.jpeg?q=70

# %%
import pandas as pd
pd.read_csv('Flipkart_scrap.csv')
# Out:
#                                           ProductName  Stars  Ratings  \
# 0        Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen    4.2      922
# 1      Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen    4.3     3664
# 2                           HP Intel Core i5 11th Gen    4.3     1286
# 3                          HP Ryzen 5 Hexa Core 5500U    4.3      103
# 4                       HP 14s Intel Core i3 11th Gen    4.3     3554
# 5               HP (2023) Intel 12th Gen N305 Core i3    4.5       15
# 6                       HP 15s Intel Core i3 12th Gen    4.3     1008
# 7   Lenovo Ideapad Gaming 3 AMD Ryzen 5 Hexa Core ...    4.3      310
# 8                                MSI Core i5 12th Gen    0.0        0
# 9                          HP Ryzen 5 Hexa Core 5500U    4.3     2723
# 10                        MSI Ryzen 5 Hexa Core 7530U    4.4      200
# 11                        MSI Ryzen 5 Hexa Core 7530U    4.4      200
# 12                         HP Ryzen 5 Hexa Core 5500U    4.3      901
# 13                         HP Ryzen 3 Quad Core 5300U    4.2     2630
# 14                               MSI Core i5 11th Gen    4.3     1234
# 15                               MSI Core i5 11th Gen    0.0        0
# 16       Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen    4.2      694
# 17           HP Victus Gaming Ryzen 5 Hexa Core 5600H    4.3      184
# 18               HP 15s (2023) Intel Core i3 13th Gen    4.1       74
# 19               HP 15s (2023) Intel Core i3 13th Gen    4.1       74
# 20                  HP Victus Ryzen 7 Octa Core 5800H    4.3       98
# 21                  HP Victus Ryzen 5 Hexa Core 5600H    4.3      302
# 22                               MSI Core i5 12th Gen    4.2      105
# 23               HP 15s (2023) Intel Core i3 13th Gen    4.1       74
#
#     Reviews     MRP CurrentPrice                           Processor  \
# 0        65  ₹68190       ₹48990  Intel Core i5 Processor (11th Gen)
# 1       320  ₹70790       ₹48990  Intel Core i5 Processor (11th Gen)
# 2        87  ₹56903       ₹49990  Intel Core i5 Processor (11th Gen)
# 3        10  ₹49631       ₹40999     AMD Ryzen 5 Hexa Core Processor
# 4       294  ₹47279       ₹35990  Intel Core i3 Processor (11th Gen)
# 5         1  ₹51134       ₹40990             Intel Core i3 Processor
# 6       116  ₹56261       ₹41390  Intel Core i3 Processor (12th Gen)
# 7        27  ₹72990       ₹48990     AMD Ryzen 5 Hexa Core Processor
# 8         0  ₹64990       ₹49990  Intel Core i5 Processor (12th Gen)
# 9       255  ₹55691       ₹43990     AMD Ryzen 5 Hexa Core Processor
# 10       27  ₹61990       ₹39990     AMD Ryzen 5 Hexa Core Processor
# 11       27  ₹64990       ₹44990     AMD Ryzen 5 Hexa Core Processor
# 12       95  ₹62754       ₹51890     AMD Ryzen 5 Hexa Core Processor
# 13      286  ₹47147       ₹35990     AMD Ryzen 3 Quad Core Processor
# 14      132  ₹67990       ₹49990  Intel Core i5 Processor (11th Gen)
# 15        0  ₹67990       ₹47990  Intel Core i5 Processor (11th Gen)
# 16       57  ₹76890       ₹49990  Intel Core i5 Processor (12th Gen)
# 17       18  ₹66769       ₹53990     AMD Ryzen 5 Hexa Core Processor
# 18        8  ₹69083       ₹46990  Intel Core i3 Processor (13th Gen)
# 19        8  ₹54552       ₹46990  Intel Core i3 Processor (13th Gen)
# 20        9  ₹95554       ₹76990     AMD Ryzen 7 Octa Core Processor
# 21       33  ₹80587       ₹65990     AMD Ryzen 5 Hexa Core Processor
# 22       15  ₹67990       ₹45990  Intel Core i5 Processor (12th Gen)
# 23        8  ₹54522       ₹46990  Intel Core i3 Processor (13th Gen)
#
#                Ram     Storage  \
# 0   16 GB DDR4 RAM  512 GB SSD
# 1    8 GB DDR4 RAM  512 GB SSD
# 2    8 GB DDR4 RAM  512 GB SSD
# 3    8 GB DDR4 RAM  512 GB SSD
# 4    8 GB DDR4 RAM  256 GB SSD
# 5    8 GB DDR4 RAM  512 GB SSD
# 6    8 GB DDR4 RAM  512 GB SSD
# 7    8 GB DDR4 RAM  512 GB SSD
# 8   16 GB DDR4 RAM  512 GB SSD
# 9    8 GB DDR4 RAM  512 GB SSD
# 10   8 GB DDR4 RAM  512 GB SSD
# 11  16 GB DDR4 RAM  512 GB SSD
# 12  16 GB DDR4 RAM  512 GB SSD
# 13   8 GB DDR4 RAM  512 GB SSD
# 14   8 GB DDR4 RAM  512 GB SSD
# 15   8 GB DDR4 RAM  512 GB SSD
# 16   8 GB DDR4 RAM  512 GB SSD
# 17   8 GB DDR4 RAM  512 GB SSD
# 18   8 GB DDR4 RAM  512 GB SSD
# 19   8 GB DDR4 RAM  512 GB SSD
# 20  16 GB DDR4 RAM  512 GB SSD
# 21  16 GB DDR4 RAM  512 GB SSD
# 22  16 GB DDR4 RAM  512 GB SSD
# 23   8 GB DDR4 RAM  512 GB SSD
#
#                                              ImageUrl
# 0   https://rukminim2.flixcart.com/image/312/312/x...
# 1   https://rukminim2.flixcart.com/image/312/312/k...
# 2   https://rukminim2.flixcart.com/image/312/312/x...
# 3   https://rukminim2.flixcart.com/image/312/312/x...
# 4   https://rukminim2.flixcart.com/image/312/312/x...
# 5   https://rukminim2.flixcart.com/image/312/312/x...
# 6   https://rukminim2.flixcart.com/image/312/312/x...
# 7   https://rukminim2.flixcart.com/image/312/312/k...
# 8   https://rukminim2.flixcart.com/image/312/312/l...
# 9   https://rukminim2.flixcart.com/image/312/312/x...
# 10  https://rukminim2.flixcart.com/image/312/312/x...
# 11  https://rukminim2.flixcart.com/image/312/312/x...
# 12  https://rukminim2.flixcart.com/image/312/312/x...
# 13  https://rukminim2.flixcart.com/image/312/312/x...
# 14  https://rukminim2.flixcart.com/image/312/312/x...
# 15  https://rukminim2.flixcart.com/image/312/312/x...
# 16  https://rukminim2.flixcart.com/image/312/312/x...
# 17  https://rukminim2.flixcart.com/image/312/312/x...
# 18  https://rukminim2.flixcart.com/image/312/312/x...
# 19  https://rukminim2.flixcart.com/image/312/312/x...
# 20  https://rukminim2.flixcart.com/image/312/312/x...
# 21  https://rukminim2.flixcart.com/image/312/312/x...
# 22  https://rukminim2.flixcart.com/image/312/312/x...
# 23  https://rukminim2.flixcart.com/image/312/312/x...
